# %% [markdown]
# ## import libraries

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## open word vectors

# %%
document_vectors = np.loadtxt('../data/document_vectors.csv', delimiter=',')

# %%
document_vectors
# Out:
# array([[ 0.04429621,  0.04455257,  0.03551343, ..., -0.07018707,
#          0.03883676, -0.00874624],
#        [ 0.03126542,  0.0503078 ,  0.03317294, ..., -0.06612314,
#          0.03029903,  0.02786769],
#        [-0.0266979 ,  0.02609669,  0.01024264, ..., -0.03874833,
#          0.00376917,  0.00482446],
#        ...,
#        [ 0.02316513,  0.03257956, -0.0055828 , ..., -0.03539034,
#          0.04172393, -0.02137971],
#        [ 0.01113984,  0.03896027,  0.00568312, ..., -0.06424962,
#          0.00413213,  0.02455431],
#        [-0.00423838,  0.02868415,  0.00031346, ..., -0.03817771,
#          0.0010829 , -0.00378635]])

# %% [markdown]
# ## open document data

# %%
import pickle

# %%
df=pickle.load(open('../data/word_frequency_df.pickle','rb'))

# %%
df
# Out:
#      submission_id    posted_time_stamp           subreddit  \
# 0           ijxoqr  2020-08-31 16:10:48  Anarcho_Capitalism
# 1           jpu2rx  2020-11-07 18:45:41        Conservative
# 2           jzta4e  2020-11-24 01:31:35        Conservative
# 3           i0ltok  2020-07-30 16:14:02        Conservative
# 4           j106fp  2020-09-28 01:24:03        Conservative
# ...            ...                  ...                 ...
# 2032        b2508a  2019-03-17 16:10:16          Republican
# 2033        9j1xpp  2018-09-26 15:12:57          Republican
# 2034        acth6r  2019-01-05 13:40:33          Republican
# 2035        gay1r8  2020-04-30 18:42:18          Republican
# 2036        fdfkmx  2020-03-04 18:34:07          Republican
#
#                                                   title  \
# 0     Rand Paul attacked by leftist mob screaming "s...
# 1              AP Has called the election for Joe Biden
# 2     Trump Administration To Start Transition Proce...
# 3             Trump calls for delay to 2020 US election
# 4     NY Times: Trump paid $750 in US income taxes i...
# ...                                                 ...
# 2032  Ilhan Omar singled out in GOP resolution conde...
# 2033  Charlie Daniels: America, It’s Time to Cool Do...
# 2034  Ocasio-Cortez floats 70 percent tax on the sup...
# 2035  California Republican Party suing state's gove...
# 2036   Michael Bloomberg Suspends Presidential Campaign
#
#                                                     url               author  \
# 0     https://www.foxnews.com/politics/rand-paul-att...  it_is_all_fake_news
# 1     https://apnews.com/article/Biden-Trump-US-elec...              Jibrish
# 2     https://www.dailywire.com/news/breaking-trump-...       Winterhold2000
# 3     https://www.bbc.com/news/world-us-canada-53597...           NoleFan723
# 4     https://apnews.com/f0e2af5f9f99de9d30dc6b90971...           pookamatic
# ...                                                 ...                  ...
# 2032  https://www.washingtonexaminer.com/news/ilhan-...               Foubar
# 2033  https://www.cnsnews.com/commentary/charlie-dan...   DEYoungRepublicans
# 2034  https://www.politico.com/story/2019/01/04/ocas...        The_seph_i_am
# 2035  https://www.cbsnews.com/news/california-republ...             raffu280
# 2036  https://www.dailywire.com/news/breaking-michae...               Yosoff
#
#       upvotes  downvotes                                       article_text  \
# 0         918         69  sen rand paul rky told fox friends he believes...
# 1       66358      27104  washington ap — democrat joe biden defeated pr...
# 2       22659      13308  the trump administration will begin the formal...
# 3       21645       8006  mr trump appears to be doing everything in his...
# 4       18944      10201  president donald trump paid just 750 in federa...
# ...       ...        ...                                                ...
# 2032      526         52  republicans are targeting rep ilhan omar dminn...
# 2033      524         52  charlie daniels it seems that – for the most p...
# 2034      520         64  “i think that it only has ever been radicals t...
# 2035      519         45  the california republican party is suing gover...
# 2036      519         16  former new york city mayor michael bloomberg a...
#
#        lean                                   word_frequencies
# 0     right  {'sen': 2, 'rand': 2, 'paul': 6, 'rky': 1, 'to...
# 1     right  {'washington': 3, 'ap': 1, 'democrat': 1, 'joe...
# 2     right  {'trump': 3, 'administration': 5, 'begin': 1, ...
# 3     right  {'mr': 1, 'trump': 1, 'appears': 1, 'everythin...
# 4     right  {'president': 12, 'donald': 3, 'trump': 20, 'p...
# ...     ...                                                ...
# 2032  right  {'republicans': 2, 'targeting': 1, 'rep': 2, '...
# 2033  right  {'charlie': 3, 'daniels': 4, 'seems': 1, 'part...
# 2034  right  {'think': 2, 'ever': 2, 'radicals': 2, 'change...
# 2035  right  {'california': 6, 'republican': 6, 'party': 6,...
# 2036  right  {'former': 4, 'new': 1, 'york': 1, 'city': 1, ...
#
# [2037 rows x 11 columns]

# %%
df_document_vectors = pd.DataFrame(document_vectors)

# %%
full_data = pd.merge(df,df_document_vectors, left_index=True, right_index=True)

full_data
# Out:
#      submission_id    posted_time_stamp           subreddit  \
# 0           ijxoqr  2020-08-31 16:10:48  Anarcho_Capitalism
# 1           jpu2rx  2020-11-07 18:45:41        Conservative
# 2           jzta4e  2020-11-24 01:31:35        Conservative
# 3           i0ltok  2020-07-30 16:14:02        Conservative
# 4           j106fp  2020-09-28 01:24:03        Conservative
# ...            ...                  ...                 ...
# 2032        b2508a  2019-03-17 16:10:16          Republican
# 2033        9j1xpp  2018-09-26 15:12:57          Republican
# 2034        acth6r  2019-01-05 13:40:33          Republican
# 2035        gay1r8  2020-04-30 18:42:18          Republican
# 2036        fdfkmx  2020-03-04 18:34:07          Republican
#
#                                                   title  \
# 0     Rand Paul attacked by leftist mob screaming "s...
# 1              AP Has called the election for Joe Biden
# 2     Trump Administration To Start Transition Proce...
# 3             Trump calls for delay to 2020 US election
# 4     NY Times: Trump paid $750 in US income taxes i...
# ...                                                 ...
# 2032  Ilhan Omar singled out in GOP resolution conde...
# 2033  Charlie Daniels: America, It’s Time to Cool Do...
# 2034  Ocasio-Cortez floats 70 percent tax on the sup...
# 2035  California Republican Party suing state's gove...
# 2036   Michael Bloomberg Suspends Presidential Campaign
#
#                                                     url               author  \
# 0     https://www.foxnews.com/politics/rand-paul-att...  it_is_all_fake_news
# 1     https://apnews.com/article/Biden-Trump-US-elec...              Jibrish
# 2     https://www.dailywire.com/news/breaking-trump-...       Winterhold2000
# 3     https://www.bbc.com/news/world-us-canada-53597...           NoleFan723
# 4     https://apnews.com/f0e2af5f9f99de9d30dc6b90971...           pookamatic
# ...                                                 ...                  ...
# 2032  https://www.washingtonexaminer.com/news/ilhan-...               Foubar
# 2033  https://www.cnsnews.com/commentary/charlie-dan...   DEYoungRepublicans
# 2034  https://www.politico.com/story/2019/01/04/ocas...        The_seph_i_am
# 2035  https://www.cbsnews.com/news/california-republ...             raffu280
# 2036  https://www.dailywire.com/news/breaking-michae...               Yosoff
#
#       upvotes  downvotes                                       article_text  \
# 0         918         69  sen rand paul rky told fox friends he believes...
# 1       66358      27104  washington ap — democrat joe biden defeated pr...
# 2       22659      13308  the trump administration will begin the formal...
# 3       21645       8006  mr trump appears to be doing everything in his...
# 4       18944      10201  president donald trump paid just 750 in federa...
# ...       ...        ...                                                ...
# 2032      526         52  republicans are targeting rep ilhan omar dminn...
# 2033      524         52  charlie daniels it seems that – for the most p...
# 2034      520         64  “i think that it only has ever been radicals t...
# 2035      519         45  the california republican party is suing gover...
# 2036      519         16  former new york city mayor michael bloomberg a...
#
#        lean  ...       290       291       292       293       294       295  \
# 0     right  ... -0.039116  0.019205 -0.083693  0.034480 -0.042531 -0.001691
# 1     right  ... -0.054582 -0.025284 -0.084579  0.003989 -0.019153 -0.034694
# 2     right  ... -0.049525 -0.023323 -0.027344  0.012907 -0.006975  0.007583
# 3     right  ... -0.019911  0.062326 -0.068449  0.031975 -0.039690 -0.018744
# 4     right  ... -0.066182  0.019025 -0.055870  0.006198 -0.013421 -0.008582
# ...     ...  ...       ...       ...       ...       ...       ...       ...
# 2032  right  ... -0.060778  0.058439 -0.048437  0.038624 -0.069729  0.014591
# 2033  right  ... -0.042085  0.030402 -0.068026  0.015028 -0.050384 -0.036858
# 2034  right  ... -0.061984  0.015763 -0.041830 -0.017687 -0.055881 -0.021292
# 2035  right  ... -0.041243 -0.024222 -0.046368 -0.010595  0.016602 -0.026344
# 2036  right  ... -0.044384 -0.021489 -0.046617  0.008226 -0.014145 -0.079493
#
#            296       297       298       299
# 0    -0.013477 -0.070187  0.038837 -0.008746
# 1     0.004952 -0.066123  0.030299  0.027868
# 2     0.013181 -0.038748  0.003769  0.004824
# 3     0.008700 -0.070276  0.038391  0.015375
# 4     0.024641 -0.041201  0.031719 -0.041490
# ...        ...       ...       ...       ...
# 2032 -0.013749 -0.050562  0.004794  0.041571
# 2033  0.016836 -0.058314  0.014821  0.015321
# 2034  0.005531 -0.035390  0.041724 -0.021380
# 2035 -0.018546 -0.064250  0.004132  0.024554
# 2036  0.000513 -0.038178  0.001083 -0.003786
#
# [2037 rows x 311 columns]

# %% [markdown]
# ## try to visualize the vector space

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(2)  # project from 300 to 2 dimensions
projected = pca.fit_transform(document_vectors)
print(document_vectors.shape)
print(projected.shape)
# Out:
# (2037, 300)
# (2037, 2)

# %%
colors = {'right':'red', 'left':'blue'}
plt.scatter(projected[:, 0], projected[:, 1],
            c=df['lean'].apply(lambda x: colors[x]), edgecolor='none', alpha=0.5)
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.show()

# %% [markdown]
# It is concerning that there is no visible separation between the two types of articles.

# %%
pca = PCA().fit(document_vectors)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %% [markdown]
# There is still hope for a good model though because the scatter plot only shows the first two principal components, which according to this curve, only explains a very small percent of total variance.

# %% [markdown]
# ## split data into test and training

# %%
df.shape
# Out:
# (2037, 11)

# %%
mapping = {'right':1, 'left':0}
Y = np.array(df['lean'].apply(lambda x: mapping[x])).T
Y.shape
# Out:
# (2037,)

# %%
X = document_vectors
X.shape
# Out:
# (2037, 300)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=0)
print('X_train: ',X_train.shape)
print('X_test: ',X_test.shape)
print('Y_train: ',Y_train.shape)
print('Y_test: ',Y_test.shape)
# Out:
# X_train:  (1527, 300)
# X_test:  (510, 300)
# Y_train:  (1527,)
# Y_test:  (510,)

# %% [markdown]
# ## Train Basic models

# %%
# Preprocessing (Label Encoder)
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Basic Models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# Ensemble Models
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier

# Validation
from sklearn.model_selection import train_test_split, cross_val_score, KFold

# Model Parameter Tuning
from sklearn.model_selection import GridSearchCV

# ML Scoring Metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
models = [
    ( 'Logistic Regression' , LogisticRegression()),
    ( 'K-Nearest Neighbors' , KNeighborsClassifier()),
    ( 'Naive Bayes' , GaussianNB()),
    ( 'Support Vector Machine' , SVC())
]

results = []
names = []

for name, model in models:
    # training with 10-fold cross validation
    Kfold = KFold(n_splits=10, random_state=3)
    cv_results = cross_val_score(model, X_train, Y_train, cv=Kfold, scoring= 'accuracy')
    
    # save results
    results.append(cv_results)
    names.append(name)

    # print out results
    print(f'{name}: \t {cv_results.mean()} +/- {cv_results.std()}')
# Out:
# Logistic Regression: 	 0.7341116271069831 +/- 0.024794686313545974
# K-Nearest Neighbors: 	 0.7498280013759889 +/- 0.03619452973879379
# Naive Bayes: 	 0.7098727210182318 +/- 0.04282449618294482
# Support Vector Machine: 	 0.7622936016511869 +/- 0.03514581269625934

# %% [markdown]
# ## training ensemble models

# %%
ensemble_models = [
    ( 'AdaBoost' , AdaBoostClassifier()),
    ( 'Bagging' , BaggingClassifier()),
    ( 'Gradient Boosted' ,  GradientBoostingClassifier()),
    ( 'Random Forest' , RandomForestClassifier())
]

for name, model in ensemble_models:
    # training with 10-fold cross validation
    Kfold = KFold(n_splits=10, random_state=3)
    cv_results = cross_val_score(model, X_train, Y_train, cv=Kfold, scoring= 'accuracy')
    
    # save results
    results.append(cv_results)
    names.append(name)

    # print out results
    print(f'{name}: \t {cv_results.mean()} +/- {cv_results.std()}')
# Out:
# AdaBoost: 	 0.7327743378052977 +/- 0.03320617747476923
# Bagging: 	 0.7255675954592363 +/- 0.0429219188954099
# Gradient Boosted: 	 0.7635835913312693 +/- 0.02532673496668851
# Random Forest: 	 0.7570390436876504 +/- 0.036987418545991455

# %% [markdown]
# ## xgboost

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier()
name='XGBoost'

# training with 10-fold cross validation
Kfold = KFold(n_splits=10, random_state=3)
cv_results = cross_val_score(model, X_train, Y_train, cv=Kfold, scoring= 'accuracy')

# save results
results.append(cv_results)
names.append(name)

# print out results
print(f'{name}: \t {cv_results.mean()} +/- {cv_results.std()}')
# Out:
# XGBoost: 	 0.7727339181286549 +/- 0.05357476235153758

# %% [markdown]
# ## auc roc curve

# %%
from sklearn.metrics import roc_curve, auc



models_for_auc_curves={}
models_for_auc_curves['Gradient Boosted']= GradientBoostingClassifier()
models_for_auc_curves['XGBoost']=XGBClassifier()
models_for_auc_curves['Support Vector Machine'] = SVC(probability=True)
models_for_auc_curves['RandomForest']=RandomForestClassifier()

trained_models = {}

for classifier in models_for_auc_curves:

    trained_classifier=models_for_auc_curves[classifier].fit(X_train, Y_train)

    trained_models[classifier] = trained_classifier

    Y_score = trained_classifier.predict_proba(X_test)[:, 1]

    fpr, tpr, _ = roc_curve(Y_test, Y_score)
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, lw=2, label=f'{classifier} (AUC-ROC = {roc_auc:.2f})')
    print(f'Done with {classifier}: {roc_auc}')


plt.tick_params()
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.gcf().set_size_inches(10, 10)
plt.savefig('../AUC-ROC_Curve.png', dpi=1200)
plt.show()
# Out:
# Done with Gradient Boosted: 0.8209293151060875
# Done with XGBoost: 0.8401571156583935
# Done with Support Vector Machine: 0.8390164834222398
# Done with RandomForest: 0.825963534073172
